# %% [markdown]
# For restaurant owners, Zomato offers a significant online presence and marketing opportunity, enabling them to showcase their offerings to a large audience of potential customers. Restaurants can manage their profiles, respond to user reviews, and improve their visibility and reputation on the platform.
#
# Zomato has become a key player in the food and restaurant industry, serving as a reliable resource for both customers seeking dining options and restaurants looking to connect with their target audience. The data generated from user interactions, reviews, and ratings on Zomato can be valuable for various data analyses and insights related to restaurant preferences, customer behavior, and dining trends.

# %% [markdown]
# Type Of Charts/Graphs/Plots :
#
# Line Plot
#
# Countplot
#
# Bar Chart
#
# Pairplot
#
# Scatter Plot
#
# Histogram

# %%
# Ratings of Restaurent
# Count of Votes
# Type of restaurnet
# Top 10 cuisines
# Online order count
# Book table count
# Top 10 Restaurent Types
# Rating distribution of online order
# Ratings vs Votes
# Top 10 disliked

# %%
# Distribution of Ratings
sns.histplot(df['rating'],bins=30);
plt.xlabel('Rating')
plt.ylabel('Count')
plt.title('Ratings of Restaurent')
plt.show()

# %%
# Distribution of Votes
sns.histplot(df['votes'],bins=30)
plt.title('Count of Votes')
# Out:
# Text(0.5, 1.0, 'Count of Votes')

# %%
df['votes'].plot(kind='hist',bins=80,xlim=(0,5000),xlabel = "Number of Votes",ylabel = 'Count',title = "Count of Votes")
plt.show()

# %%
df['type'].value_counts().plot(kind = 'bar',xlabel="Type", ylabel ='count',title = 'Types of Restaurent');

# %%
top_cuisines = df['cuisines'].value_counts().head(10)
plt.figure(figsize=(10,6))
sns.barplot(x=top_cuisines.index,y=top_cuisines.values)
plt.xticks(rotation=45,ha='right')
plt.xlabel('Cuisines')
plt.ylabel('Count')
plt.title('Top 10 Cuisines')
plt.show()

# %%
online_order = df['online_order'].value_counts()
plt.figure(figsize=(7,7))
sns.barplot(x=online_order.index, y = online_order.values)
plt.xlabel('online_order')
plt.ylabel('Count')
plt.title('online_order Count')
plt.show()

# %%
book_table = df['book_table'].value_counts()
plt.figure(figsize = (6,6))
sns.barplot(x=book_table.index, y = book_table.values)
plt.xlabel('book_table')
plt.ylabel('Count')
plt.title('book Table Count')
plt.show()

# %%
df['book_table'].value_counts()
# Out:
# No     25505
# Yes     4831
# Name: book_table, dtype: int64

# %%
top_rest = df['rest_type'].value_counts().head(10)
plt.figure(figsize=(10,6))
sns.barplot(x=top_rest.index,y=top_rest.values)
plt.xticks(rotation=45,ha='right')
plt.xlabel('rest_type')
plt.ylabel('Count')
plt.title('Top 10 Rest_Type')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x = 'online_order', y ='rating',data = df)
plt.xlabel('Online Order')
plt.ylabel('Rating')
plt.title('Rating distribution for online Order')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x = 'rating',y = 'votes',data = df)
plt.xlabel('rating')
plt.ylabel('Votes')
plt.title('distribution of rating vs votes')
plt.show()

# %%
plt.figure(figsize= (8,6))
sns.scatterplot(x = 'rating',y='votes',data = df)
plt.xlabel('Rating')
plt.ylabel('Votes')
plt.title('Rating vs Votes')
plt.show()

# %%
top_dish_liked = df['dish_liked'].value_counts().head(10)
top_dish_liked
# Out:
# None               13213
# Biryani              135
# Chicken Biryani       51
# Paratha               47
# Friendly Staff        46
# Waffles               44
# Masala Dosa           36
# Coffee                32
# Pizza                 30
# Burgers               27
# Name: dish_liked, dtype: int64

# %%
top_dish_liked = df['dish_liked'].value_counts().head(10)
plt.figure(figsize = (10,6))
sns.barplot(x = top_dish_liked.index, y=top_dish_liked.values)
plt.xticks(rotation=45, ha='right')
plt.xlabel('Dish_Liked')
plt.ylabel('Count')
plt.title('Top 10 Dish Liked')
plt.show()

# %%
top_location = df['location'].value_counts().head(10)
plt.figure(figsize=(10,6))
sns.barplot(x=top_location.index,y=top_location.values)
plt.xticks(rotation=45,ha='right')
plt.xlabel('location')
plt.ylabel('Count')
plt.title('Top 10 location')
plt.show()

# %%
top_Restaurent_name = df['Restaurent_name'].value_counts().head(10)
plt.figure(figsize=(10,6))
sns.barplot(x=top_Restaurent_name.index,y=top_Restaurent_name.values)
plt.xticks(rotation=45,ha='right')
plt.xlabel('Restaurent_name')
plt.ylabel('Count')
plt.title('Top 10 Restaurent_name')
plt.show()

# %%
sns.countplot(x = 'Restaurent_name' ,data = df)
# Out:
# <AxesSubplot:xlabel='Restaurent_name', ylabel='count'>

# %%
top_location = df['location'].value_counts().head(10)
plt.figure(figsize=(10,10))
sns.barplot(x=top_location.index,y=top_location.values)
plt.xticks(rotation=45,ha='right')
plt.xlabel('location')
plt.ylabel('Count')
plt.title('Top 10 location')
plt.show()

# %%
plt.figure(figsize = (10,10))
sns.countplot(x = 'location', data=df);

# %%
sns.pairplot(df);

# %%
top_approx_cost = df['approx_cost'].value_counts().head(10)
plt.figure(figsize=(10,10))
sns.displot(x=top_approx_cost.index,y=top_approx_cost.values)
plt.xticks(rotation=45,ha='right')
plt.xlabel('approx_cost')
plt.ylabel('Count')
plt.title('Top 10 approx_cost')
plt.show()

# %%
sns.displot(df["approx_cost"],kde = False)

# %%
df.head()
# Out:
#          Restaurent_name online_order book_table  rating  votes      location  \
# 0                  Jalsa          Yes        Yes     4.1    775  Banashankari
# 1         Spice Elephant          Yes         No     4.1    787  Banashankari
# 2        San Churro Cafe          Yes         No     3.8    918  Banashankari
# 3  Addhuri Udupi Bhojana           No         No     3.7     88  Banashankari
# 4          Grand Village           No         No     3.8    166  Basavanagudi
#
#              rest_type                                         dish_liked  \
# 0        Casual Dining  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1        Casual Dining  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Cafe, Casual Dining  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3          Quick Bites                                        Masala Dosa
# 4        Casual Dining                                Panipuri, Gol Gappe
#
# ...

# %%
df.columns
# Out:
# Index(['Restaurent_name', 'online_order', 'book_table', 'rating', 'votes',
#        'location', 'rest_type', 'dish_liked', 'cuisines', 'approx_cost',
#        'type'],
#       dtype='object')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("C:\\Users\\GOURAV NEGI\\Downloads\\archive (6)\\zomatocleaned.csv")
df.head()
# Out:
#    Unnamed: 0                   name online_order book_table  rating  votes  \
# 0           0                  Jalsa          Yes        Yes     4.1    775
# 1           1         Spice Elephant          Yes         No     4.1    787
# 2           2        San Churro Cafe          Yes         No     3.8    918
# 3           3  Addhuri Udupi Bhojana           No         No     3.7     88
# 4           4          Grand Village           No         No     3.8    166
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
# 3  Banashankari          Quick Bites
# 4  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# ...

# %%
df.drop(columns = 'Unnamed: 0',inplace = True)

# %%
df.head()
# Out:
#                     name online_order book_table  rating  votes      location  \
# 0                  Jalsa          Yes        Yes     4.1    775  Banashankari
# 1         Spice Elephant          Yes         No     4.1    787  Banashankari
# 2        San Churro Cafe          Yes         No     3.8    918  Banashankari
# 3  Addhuri Udupi Bhojana           No         No     3.7     88  Banashankari
# 4          Grand Village           No         No     3.8    166  Basavanagudi
#
#              rest_type                                         dish_liked  \
# 0        Casual Dining  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1        Casual Dining  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Cafe, Casual Dining  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3          Quick Bites                                        Masala Dosa
# 4        Casual Dining                                Panipuri, Gol Gappe
#
# ...

# %%
df.rename(columns = {'name':'Restaurent_name'},inplace = True)

# %%
df.head()
# Out:
#          Restaurent_name online_order book_table  rating  votes      location  \
# 0                  Jalsa          Yes        Yes     4.1    775  Banashankari
# 1         Spice Elephant          Yes         No     4.1    787  Banashankari
# 2        San Churro Cafe          Yes         No     3.8    918  Banashankari
# 3  Addhuri Udupi Bhojana           No         No     3.7     88  Banashankari
# 4          Grand Village           No         No     3.8    166  Basavanagudi
#
#              rest_type                                         dish_liked  \
# 0        Casual Dining  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1        Casual Dining  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Cafe, Casual Dining  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3          Quick Bites                                        Masala Dosa
# 4        Casual Dining                                Panipuri, Gol Gappe
#
# ...

# %%
df.isnull().sum()
# Out:
# Restaurent_name        0
# online_order           0
# book_table             0
# rating                 0
# votes                  0
# location               0
# rest_type            107
# dish_liked         13213
# cuisines               6
# approx_cost            0
# type                2584
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 2749

# %%
dup.duplicated().sum()
# Out:
# 0

# %%
dup = df.drop_duplicates()
print(dup)
# Out:
#                                          Restaurent_name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 30331                         The Farm House Bar n Grill           No
# 30332                                            Bhagini           No
# 30333  Best Brews - Four Points by Sheraton Bengaluru...           No
# 30334  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 30335                       The Nest - The Den Bengaluru           No
#
#       book_table  rating  votes                    location  \
# 0            Yes     4.1    775                Banashankari
# ...

# %%
df.dropna()
df.head()
# Out:
#          Restaurent_name online_order book_table  rating  votes      location  \
# 0                  Jalsa          Yes        Yes     4.1    775  Banashankari
# 1         Spice Elephant          Yes         No     4.1    787  Banashankari
# 2        San Churro Cafe          Yes         No     3.8    918  Banashankari
# 3  Addhuri Udupi Bhojana           No         No     3.7     88  Banashankari
# 4          Grand Village           No         No     3.8    166  Basavanagudi
#
#              rest_type                                         dish_liked  \
# 0        Casual Dining  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1        Casual Dining  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Cafe, Casual Dining  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3          Quick Bites                                        Masala Dosa
# 4        Casual Dining                                Panipuri, Gol Gappe
#
# ...

# %%
df.isnull().sum()
# Out:
# Restaurent_name        0
# online_order           0
# book_table             0
# rating                 0
# votes                  0
# location               0
# rest_type            107
# dish_liked         13213
# cuisines               6
# approx_cost            0
# type                2584
# dtype: int64

# %%
df['cuisines'].isnull().value_counts()
# Out:
# False    30330
# True         6
# Name: cuisines, dtype: int64

# %%
df['rest_type'].fillna('None',inplace=True)

# %%
df['type'].fillna("None",inplace=True)

# %%
df['cuisines'].fillna("None",inplace = True)

# %%
df['dish_liked'].fillna('None',inplace = True)

# %%
df.isnull().sum()
# Out:
# Restaurent_name    0
# online_order       0
# book_table         0
# rating             0
# votes              0
# location           0
# rest_type          0
# dish_liked         0
# cuisines           0
# approx_cost        0
# type               0
# dtype: int64

# %%
unq= df['Restaurent_name'].unique()
unq
# Out:
# array(['Jalsa', 'Spice Elephant', 'San Churro Cafe', ...,
#        'The Nest - The Den Bengaluru', 'Nawabs Empire',
#        'SeeYa Restaurant'], dtype=object)

# %%
df.head()
# Out:
#          Restaurent_name online_order book_table  rating  votes      location  \
# 0                  Jalsa          Yes        Yes     4.1    775  Banashankari
# 1         Spice Elephant          Yes         No     4.1    787  Banashankari
# 2        San Churro Cafe          Yes         No     3.8    918  Banashankari
# 3  Addhuri Udupi Bhojana           No         No     3.7     88  Banashankari
# 4          Grand Village           No         No     3.8    166  Basavanagudi
#
#              rest_type                                         dish_liked  \
# 0        Casual Dining  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1        Casual Dining  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Cafe, Casual Dining  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3          Quick Bites                                        Masala Dosa
# 4        Casual Dining                                Panipuri, Gol Gappe
#
# ...
